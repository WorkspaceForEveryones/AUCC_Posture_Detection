# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import time

# %%
# Initialize mediapipe pose class.
mp_pose = mp.solutions.pose

# Setup the Pose function for images - independently for the images standalone processing.
pose_image = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Initialize mediapipe drawing class - to draw the landmarks points.
mp_drawing = mp.solutions.drawing_utils

# %%
def detectPose(image_pose, pose, draw=False, display=False):
    original_image = image_pose.copy()
    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)
    resultant = pose.process(image_in_RGB)

    if resultant.pose_landmarks and draw:    

        mp_drawing.draw_landmarks(image=original_image, landmark_list=resultant.pose_landmarks,
                                  connections=mp_pose.POSE_CONNECTIONS,
                                  landmark_drawing_spec=mp_drawing.DrawingSpec(color=(255,0,0),
                                                                               thickness=3, circle_radius=3),
                                  connection_drawing_spec=mp_drawing.DrawingSpec(color=(49,125,237),
                                                                               thickness=2, circle_radius=2))

#     if resultant.pose_landmarks:
#         mp_drawing.draw_landmarks(original_image, resultant.pose_landmarks, mp_pose.POSE_CONNECTIONS)
       
        for id, lm in enumerate(resultant.pose_landmarks.landmark):
            h, w, c = original_image.shape
            print(id, lm)
            cx, cy = int(lm.x * w), int(lm.y * h)
#             cv2.circle(original_image, (cx, cy), 5, (49,125,237), cv2.FILLED)
            
    pTime = 0
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    
    if display:

        plt.figure(figsize=[22,22])
#         plt.subplot(121);plt.imshow(image_pose[:,:,::-1]);plt.title("Input Image");plt.axis('off');
        plt.subplot(122);plt.imshow(original_image[:,:,::-1]);plt.title("Pose detected Image");plt.axis('off');

    else:

        return results

# %%
# read image from the specified path to detect the pose
image_path = './postures/ex5.jpg'
output = cv2.imread(image_path)
detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex5-1.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex6.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex6-1.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex7.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex7-1.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex8.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)

# image_path = './postures/ex8-1.jpg'
# output = cv2.imread(image_path)
# detectPose(output, pose_image, draw=True, display=True)
# Out:
# 0 x: 0.46381813287734985
# y: 0.13562554121017456
# z: -0.267167866230011
# visibility: 0.9998735189437866
#
# 1 x: 0.46302661299705505
# y: 0.11348020285367966
# z: -0.23117615282535553
# visibility: 0.9996639490127563
#
# 2 x: 0.4620696008205414
# y: 0.11317920684814453
# z: -0.23142781853675842
# visibility: 0.9996418952941895
#
# 3 x: 0.4605407118797302
# y: 0.11271695047616959
# z: -0.23168176412582397
# visibility: 0.9997249245643616
#
# 4 x: 0.4529413878917694
# y: 0.11148768663406372
# z: -0.30720096826553345
# visibility: 0.9996604919433594
#
# 5 x: 0.44533979892730713
# y: 0.10984697937965393
# z: -0.30718761682510376
# visibility: 0.9996373653411865
#
# 6 x: 0.43692028522491455
# y: 0.10778871178627014
# z: -0.3070574104785919
# visibility: 0.9996728897094727
#
# 7 x: 0.4169203042984009
# y: 0.10990933328866959
# z: -0.041321929544210434
# visibility: 0.9994792342185974
#
# 8 x: 0.39135822653770447
# y: 0.10477632284164429
# z: -0.3887331187725067
# ...
